# %%
# Day 16 of py challenge
# Create a program that scrapes a website (e.g., news headlines from a news site) and displays the
# results.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue"
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
table = soup.find('table', class_="wikitable sortable")

# %%
world_titles = table.find_all('th')
world_table_titles = [title.text[:-1] for title in world_titles]

# %%
df = pd.DataFrame(columns=world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD millions), Revenue growth, Employees, Headquarters]
# Index: []

# %%
column_data = table.find_all('tr')
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_data = [data.text[:-2] for data in row_data]
    length = len(df)
    df.loc[length] = individual_data

# %%
df
# Out:
#    Rank                 Name                   Industry  \
# 0                     Walmar                      Retai
# 1                      Amazo  Retail and cloud computin
# 2                       Appl        Electronics industr
# 3          UnitedHealth Grou                  Healthcar
# 4          Berkshire Hathawa                Conglomerat
# ..  ...                  ...                        ...
# 95    9                  TIA                  Financial
# 96    9                   CH     Agriculture cooperativ
# 97    9  Bristol-Myers Squib     Pharmaceutical industr
# 98    9  Dow Chemical Compan           Chemical industr
# 99   10              Best Bu                      Retai
#
#    Revenue (USD millions) Revenue growth Employees  \
# 0                  648,12            6.0  2,100,00
# 1                  574,78           11.9  1,525,00
# 2                  383,48           -2.8    161,00
# 3                  371,62           14.6    440,00
# ...
